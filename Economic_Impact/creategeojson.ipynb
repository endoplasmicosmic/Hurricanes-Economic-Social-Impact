# %%
import pandas as pd
import geojson

# %%
df = pd.read_csv('data2.csv')

# %%
df
# Out:
#      Start Year  Start Month  Start Day  End Year  End Month  End Day  \
# 0          2002            9         20      2002          9       20
# 1          2002            9         20      2002          9       20
# 2          2002            9         26      2002          9       27
# 3          2002            9         26      2002          9       27
# 4          2002            9         26      2002          9       27
# ..          ...          ...        ...       ...        ...      ...
# 194        2021            8         28      2021          9        2
# 195        2021            8         28      2021          9        2
# 196        2021            8         28      2021          9        2
# 197        2021            8         28      2021          9        2
# 198        2023           10         22      2023         10       25
#
#                               Location  Total Deaths  No. Affected  \
# ...

# %%
features = []
for _, row in df.iterrows():
    feature = {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [row["Longitude"], row["Latitude"]]
        },
        "properties": {
            "Location": row["Location"],
            "Total Deaths": row["Total Deaths"],
            "No. Affected": row["No. Affected"],
            "Total Affected": row["Total Affected"],
            "Insured Damage ('000 US$)": row["Insured Damage ('000 US$)"],
            "Total Damage ('000 US$)": row["Total Damage ('000 US$)"],
            "Magnitude": row["Magnitude"],
            "Magnitude Scale": row["Magnitude Scale"]
        }
    }
    features.append(feature)

# %%
geojson_data = {
    "type": "FeatureCollection",
    "features": features
}

# %%
with open('data.geojson', 'w') as f:
    geojson.dump(geojson_data, f)
